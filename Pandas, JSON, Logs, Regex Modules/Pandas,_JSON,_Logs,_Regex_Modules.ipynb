# %%
import pandas as pd

# %%
covid_df = pd.read_csv("/content/worldometer_data.csv")
covid_df.head() # pandas.dataframe.tail()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %% [markdown]
# # Exploration of Dataset

# %%
covid_df.info()  # provides information about the DataFrame, including data types and non-null values
covid_df.shape  # returns the number of rows and columns in the DataFrame
covid_df.columns  # returns the column names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
covid_df.describe()  # generates descriptive statistics for numerical columns
# Out:
#          Population    TotalCases     NewCases    TotalDeaths   NewDeaths  \
# count  2.080000e+02  2.090000e+02     4.000000     188.000000    3.000000
# mean   3.041549e+07  9.171850e+04  1980.500000    3792.590426  300.000000
# std    1.047661e+08  4.325867e+05  3129.611424   15487.184877  451.199512
# min    8.010000e+02  1.000000e+01    20.000000       1.000000    1.000000
# 25%    9.663140e+05  7.120000e+02    27.500000      22.000000   40.500000
# 50%    7.041972e+06  4.491000e+03   656.000000     113.000000   80.000000
# 75%    2.575614e+07  3.689600e+04  2609.000000     786.000000  449.500000
# max    1.381345e+09  5.032179e+06  6590.000000  162804.000000  819.000000
#
#        TotalRecovered  NewRecovered   ActiveCases  Serious,Critical  \
# count    2.050000e+02      3.000000  2.050000e+02        122.000000
# mean     5.887898e+04   1706.000000  2.766433e+04        534.393443
# std      2.566984e+05   2154.779803  1.746327e+05       2047.518613
# ...

# %% [markdown]
# # Acessing Data

# %%
print(covid_df.loc[7])  # returns a specific row as a Series based on the row index

print(50*"-")
covid_df.loc[8:16, 'TotalDeaths']  # returns a specific range of rows for a column
# Out:
# Country/Region              Chile
# Continent           South America
# Population             19132514.0
# TotalCases                 366671
# NewCases                      NaN
# TotalDeaths                9889.0
# NewDeaths                     NaN
# TotalRecovered           340168.0
# NewRecovered                  NaN
# ActiveCases               16614.0
# Serious,Critical           1358.0
# Tot Cases/1M pop          19165.0
# Deaths/1M pop               517.0
# TotalTests              1760615.0
# Tests/1M pop              92022.0
# WHO Region               Americas
# Name: 7, dtype: object
# --------------------------------------------------
# 8     11939.0
# 9     28500.0
# 10    17976.0
# 11    46413.0
# 12     3055.0
# 13     6035.0
# 14     3306.0
# 15    35187.0
# 16     5798.0
# Name: TotalDeaths, dtype: float64

# %%
print(covid_df.iloc[1])

print(50*"-")

covid_df.iloc[1:3, 1:6]
# Out:
# Country/Region             Brazil
# Continent           South America
# Population            212710692.0
# TotalCases                2917562
# NewCases                      NaN
# TotalDeaths               98644.0
# NewDeaths                     NaN
# TotalRecovered          2047660.0
# NewRecovered                  NaN
# ActiveCases              771258.0
# Serious,Critical           8318.0
# Tot Cases/1M pop          13716.0
# Deaths/1M pop               464.0
# TotalTests             13206188.0
# Tests/1M pop              62085.0
# WHO Region               Americas
# Name: 1, dtype: object
# --------------------------------------------------
#        Continent    Population  TotalCases  NewCases  TotalDeaths
# 1  South America  2.127107e+08     2917562       NaN      98644.0
# 2           Asia  1.381345e+09     2025409       NaN      41638.0

# %% [markdown]
# # Filtering data

# %%
covid_df["TotalCases"].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0      5032179
# 1      2917562
# 2      2025409
# 3       871894
# 4       538184
#         ...
# 204         13
# 205         13
# 206         13
# 207         12
# 208         10
# Name: TotalCases, Length: 209, dtype: int64>

# %%
covid_df[covid_df['TotalCases'] > 2025409]  # filters rows based on a condition

covid_df.query('TotalCases > 2025409')  # alternative way to filter rows based on a condition
# Out:
#   Country/Region      Continent   Population  TotalCases  NewCases  \
# 0            USA  North America  331198130.0     5032179       NaN
# 1         Brazil  South America  212710692.0     2917562       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# 1            8318.0           13716.0          464.0  13206188.0
#
#    Tests/1M pop WHO Region
# 0      190640.0   Americas
# 1       62085.0   Americas

# %% [markdown]
# # Handling missing data:

# %%
covid_df
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
covid_df.sort_values('NewCases', ascending=True)
# Out:
#             Country/Region      Continent   Population  TotalCases  NewCases  \
# 72                S. Korea           Asia   51273732.0       14519      20.0
# 146                Jamaica  North America    2962478.0         958      30.0
# 28                 Bolivia  South America   11688459.0       86423    1282.0
# 5                   Mexico  North America  129066160.0      462690    6590.0
# 0                      USA  North America  331198130.0     5032179       NaN
# ..                     ...            ...          ...         ...       ...
# 204             Montserrat  North America       4992.0          13       NaN
# 205  Caribbean Netherlands  North America      26247.0          13       NaN
# 206       Falkland Islands  South America       3489.0          13       NaN
# 207           Vatican City         Europe        801.0          12       NaN
# 208         Western Sahara         Africa     598682.0          10       NaN
#
# ...

# %% [markdown]
# # Logging and REGEX

# %%
import logging

# %%
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
import re

pattern = r'the'  # regular expression pattern
text = 'The quick brown fox jumps over the lazy dog'
match = re.search(pattern, text)  # search for the pattern in the text
if match:
    print('Pattern found')
else:
    print('Pattern not found')
# Out:
# Pattern found

# %%
pattern = r'(\d+)-(\d+)-(\d+)'  # pattern to match a date in the format "yyyy-mm-dd"
text = 'Today is 2023-07-07'
match = re.search(pattern, text)
if match:
    year = match.group(1)
    month = match.group(2)
    day = match.group(3)
    print(f'Date: {year}-{month}-{day}')
else:
    print('Date not found')
# Out:
# Date: 2023-07-07
